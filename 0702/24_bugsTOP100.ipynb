# %%
import warnings
warnings.filterwarnings(action='ignore')
import requests
from bs4 import BeautifulSoup
from datetime import datetime as dt

# %%
print(dt.now())
# Out:
# 2021-07-02 19:45:05.520838

# %%
targetSite = 'https://music.bugs.co.kr/chart'
request = requests.get(targetSite)
# print(request)
html = request.text
# print(html)
soup = BeautifulSoup(html, 'html.parser')
# print(soup)

# %%
# 노래 제목 크롤링
# 노래 제목은 'class' 속성이 'titla'인 <p> 태그 내부에 있다.
titles = soup.findAll('p', {'class': 'title'})
# print(titles)
# print(len(titles))
for title in titles:
    # print(title.text.strip())
    # print(title.text.split('\n')[1])
    print(title.text.strip().split('\n')[0])
# Out:
# 바라만 본다
# Next Level
# 나는 너 좋아
# 비 오는 날 듣기 좋은 노래 (Feat. Colde)
# 나를 아는 사람
# Alcohol-Free
# 하루만 더
# 치맛바람 (Chi Mat Ba Ram)
# Butter
# Dun Dun Dance
# Bad Habits
# 신호등
# Good Bye
# 헤픈 우연
# 비와 당신
# 해야 해
# ASAP
# 안녕 (Hello)
# 롤린 (Rollin')
# 가을 우체국 앞에서
# Peaches (feat. Daniel Caesar, Giveon)
# 운전만해 (We Ride)
# 추적이는 여름 비가 되어
# Hello Future
# 라일락
# 상상더하기
# 상상더하기
# Dynamite
# Loving You Girl (feat. Hkeem)
# Celebrity
# Off My Face
# Ready to love
# Your voice
# 체념
# Timeless
# Kiss Me More (feat. SZA)
# 마.피.아. In the morning
# Black Mamba
# 내 입술 따뜻한 커피처럼
# Dolphin
# 내 손을 잡아
# Leave Before You Love Me
# 서울의 잠 못 이루는 밤 (Feat. 이수현)
# 어푸 (Ah puh)
# WE GO
# 허리춤
# 사이렌 Remix (Feat. UNEDUCATED KID, Paul Blanco)
# 에잇(Prod.&Feat. SUGA of BTS)
# Leave The Door Open
# 좋을텐데 (If Only) (Feat. 폴킴)
# Coin
# 다정히 내 이름을 부르면
# 멜로디
# 우리집
# Blueming
# On The Ground
# Lovesick Girls
# Beautiful Mistakes
# Life Goes On
# 어떻게 이별까지 사랑하겠어, 널 사랑하는 거지
# Savage Love (Laxed - Siren Beat) (BTS Remix)
# ...

# %%
# 아티스트 크롤링
# 가수 이름은 'class' 속성이 'artist'인 <p> 태그 내부에 있다.
artists = soup.findAll('p', {'class': 'artist'})
# print(artists)
# print(len(artists))
for artist in artists:
    # print(artist.text.strip())
    # print(artist.text.split('\n')[1])
    print(artist.text.strip().split('\n')[0])
# Out:
# MSG워너비(M.O.M)
# aespa
# 장범준
# 에픽하이 (EPIK HIGH)
# MSG워너비(정상동기)
# TWICE (트와이스)
# 빅마마(Big Mama)
# 브레이브걸스(Brave Girls)
# 방탄소년단
# 오마이걸(OH MY GIRL)
# Ed Sheeran(에드 시런)
# 이무진
# XIA(준수)
# 헤이즈(Heize)
# 이무진
# 2PM
# STAYC(스테이씨)
# 조이 (JOY)
# 브레이브걸스(Brave Girls)
# 김대명
# Justin Bieber(저스틴 비버)
# 브레이브걸스(Brave Girls)
# 장범준
# NCT DREAM
# 아이유(IU)
# 라붐(LABOUM)
# MSG워너비 TOP 8 (별루지, 김정수, 강창모, 정기석, 이동휘, 이상이, 박재정, 원슈타인)
# 방탄소년단
# Peder Elias
# 아이유(IU)
# Justin Bieber(저스틴 비버)
# 세븐틴(SEVENTEEN)
# 강승윤
# MSG워너비(정상동기)
# SG워너비
# Doja Cat(도자 캣)
# ITZY (있지)
# aespa
# 청하
# 오마이걸(OH MY GIRL)
# 아이유(IU)
# Marshmello(마시멜로)
# 10CM
# 아이유(IU)
# 프로미스나인
# 오반 (OVAN)
# 호미들
# 아이유(IU)
# Bruno Mars(브루노 마스)
# 조이 (JOY)
# 아이유(IU)
# 경서예지
# ASH ISLAND
# 2PM
# 아이유(IU)
# 로제(ROSÉ)
# BLACKPINK
# Maroon 5(마룬 파이브)
# 방탄소년단
# AKMU (악동뮤지션)
# Jawsh 685
# 장범준
# 방탄소년단
# DPR LIVE
# SG워너비
# 다비치
# John K
# Pink Sweat$
# 브레이브걸스(Brave Girls)
# 오마이걸(OH MY GIRL)
# 양요섭
# SG워너비
# The Weeknd(위켄드)
# 폴킴(Paul Kim)
# Anne-Marie(앤 마리)
# NCT DREAM
# 전상근
# Stellar
# ...

# %%
print(dt.now())
for i in range(100):
    title = titles[i].text.strip().split('\n')[0]
    artist = artists[i].text.strip().split('\n')[0]
    print('{0:3d}위 {1} - {2}'.format(i + 1, artist, title))
# Out:
# 2021-07-02 19:45:06.228935
#   1위 MSG워너비(M.O.M) - 바라만 본다
#   2위 aespa - Next Level
#   3위 장범준 - 나는 너 좋아
#   4위 에픽하이 (EPIK HIGH) - 비 오는 날 듣기 좋은 노래 (Feat. Colde)
#   5위 MSG워너비(정상동기) - 나를 아는 사람
#   6위 TWICE (트와이스) - Alcohol-Free
#   7위 빅마마(Big Mama) - 하루만 더
#   8위 브레이브걸스(Brave Girls) - 치맛바람 (Chi Mat Ba Ram)
#   9위 방탄소년단 - Butter
#  10위 오마이걸(OH MY GIRL) - Dun Dun Dance
#  11위 Ed Sheeran(에드 시런) - Bad Habits
#  12위 이무진 - 신호등
#  13위 XIA(준수) - Good Bye
#  14위 헤이즈(Heize) - 헤픈 우연
#  15위 이무진 - 비와 당신
#  16위 2PM - 해야 해
#  17위 STAYC(스테이씨) - ASAP
#  18위 조이 (JOY) - 안녕 (Hello)
#  19위 브레이브걸스(Brave Girls) - 롤린 (Rollin')
#  20위 김대명 - 가을 우체국 앞에서
#  21위 Justin Bieber(저스틴 비버) - Peaches (feat. Daniel Caesar, Giveon)
#  22위 브레이브걸스(Brave Girls) - 운전만해 (We Ride)
#  23위 장범준 - 추적이는 여름 비가 되어
#  24위 NCT DREAM - Hello Future
#  25위 아이유(IU) - 라일락
#  26위 라붐(LABOUM) - 상상더하기
#  27위 MSG워너비 TOP 8 (별루지, 김정수, 강창모, 정기석, 이동휘, 이상이, 박재정, 원슈타인) - 상상더하기
#  28위 방탄소년단 - Dynamite
#  29위 Peder Elias - Loving You Girl (feat. Hkeem)
# ...

# %%
# 크롤링한 결과를 텍스트 파일에 저장한다.
# file = open('bugsTOP100.txt', 'w')
# UnicodeEncodeError: 'cp949' codec can't encode character '\xf1' in position 29: illegal multibyte sequence
# 크롤링 데이터를 텍스트 파일에 저장하려는 경우 위와 같이 한글 인코딩 문제로 UnicodeEncodeError가 발생될 수 있다.
# 에러가 발생되면 file = open('bugsTOP100.txt', 'w', -1, 'UTF-8')
file = open('bugsTOP100.txt', 'w', -1, 'UTF-8')

file.write('{} 현재 Bugs 뮤직 실시간 TOP 100\n'.format(dt.now()))
for i in range(100):
    title = titles[i].text.strip().split('\n')[0]
    artist = artists[i].text.strip().split('\n')[0]
    data = '{0:3d}위 {1} - {2}'.format(i + 1, artist, title)
    file.write(data + '\n')
    
file.close()
print('bugsTOP100.txt 파일에 쓰기 완료')
# Out:
# bugsTOP100.txt 파일에 쓰기 완료

# %%
# 텍스트 파일에 저장된 데이터를 읽어서 출력한다.
try:
    file = open('bugsTOP100.txt', 'r', -1, 'UTF-8')
    # readLines() 메소드는 텍스트 파일의 내용 전체를 한꺼번에 읽어서 리스트로 리턴한다.
    lines = file.readlines()
    for line in lines:
        # print(line, end='')
        print(line.strip())
except FileNotFoundError:
    print('bugsTOP100.txt 파일이 디스크에 없습니다.')
# Out:
# 2021-07-02 19:45:06.293461 현재 Bugs 뮤직 실시간 TOP 100
# 1위 MSG워너비(M.O.M) - 바라만 본다
# 2위 aespa - Next Level
# 3위 장범준 - 나는 너 좋아
# 4위 에픽하이 (EPIK HIGH) - 비 오는 날 듣기 좋은 노래 (Feat. Colde)
# 5위 MSG워너비(정상동기) - 나를 아는 사람
# 6위 TWICE (트와이스) - Alcohol-Free
# 7위 빅마마(Big Mama) - 하루만 더
# 8위 브레이브걸스(Brave Girls) - 치맛바람 (Chi Mat Ba Ram)
# 9위 방탄소년단 - Butter
# 10위 오마이걸(OH MY GIRL) - Dun Dun Dance
# 11위 Ed Sheeran(에드 시런) - Bad Habits
# 12위 이무진 - 신호등
# 13위 XIA(준수) - Good Bye
# 14위 헤이즈(Heize) - 헤픈 우연
# 15위 이무진 - 비와 당신
# 16위 2PM - 해야 해
# 17위 STAYC(스테이씨) - ASAP
# 18위 조이 (JOY) - 안녕 (Hello)
# 19위 브레이브걸스(Brave Girls) - 롤린 (Rollin')
# 20위 김대명 - 가을 우체국 앞에서
# 21위 Justin Bieber(저스틴 비버) - Peaches (feat. Daniel Caesar, Giveon)
# 22위 브레이브걸스(Brave Girls) - 운전만해 (We Ride)
# 23위 장범준 - 추적이는 여름 비가 되어
# 24위 NCT DREAM - Hello Future
# 25위 아이유(IU) - 라일락
# 26위 라붐(LABOUM) - 상상더하기
# 27위 MSG워너비 TOP 8 (별루지, 김정수, 강창모, 정기석, 이동휘, 이상이, 박재정, 원슈타인) - 상상더하기
# 28위 방탄소년단 - Dynamite
# 29위 Peder Elias - Loving You Girl (feat. Hkeem)
# ...
